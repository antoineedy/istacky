# %%
from src.istack.utils import *
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
#ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
img1 = Image.open("image_example/img1.jpg")
img2 = Image.open("image_example/img2.jpg")
img3 = Image.open("image_example/img3.jpg")
img4 = Image.open("image_example/img4.jpg")
moutons = Image.open("image_example/moutons.jpg")
barbapapa = Image.open("image_example/barbapapa.jpg")

# %%
blended= BlendedImage(img1, [img2, img4])
blended.create_image()

# %%
blended.editor()

# %%
code = "#0.5-0-0-1-0-255,255,255-0-1-0,0,0,0#0.5-231-163-1-0-255,255,255-0-1-0,50,0,0c0,0,0,0"

new_image = BlendedImage(img1, [img4, img2], code = code)
new_image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=626x417>
